# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

# %%
MTH = pd.read_csv('monthly.csv')

# %%
MTH.head()
# Out:
#   month  accidents  injured
# 0   Jan       5441     7679
# 1   Fab       5334     7435
# 2   Mar       5554     7323
# 3   Apr       5987     7964
# 4   May       8049    11047

# %%
sns.lineplot(x=MTH.month, y=MTH.accidents)
sns.lineplot(x=MTH.month, y=MTH.injured)
plt.ylim(0,12000)
# Out:
# (0.0, 12000.0)
