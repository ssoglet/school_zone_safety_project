# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

# %%
HR = pd.read_csv('hourly.csv')

# %%
HR.head()
# Out:
#    time  accidents  injured
# 0     1        373      519
# 1     3         77      100
# 2     5         97      135
# 3     7        895     1172
# 4     9       7220     9984

# %%
sns.lineplot(x=HR.time, y=HR.accidents)
sns.lineplot(x=HR.time, y=HR.injured)
plt.ylim(0,25000)
# Out:
# (0.0, 25000.0)
